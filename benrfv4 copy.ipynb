# %%
import warnings
warnings.filterwarnings("ignore")

import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.base import clone
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_recall_fscore_support,
    classification_report,
    cohen_kappa_score,
    f1_score,
)

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)

DATA_PATH = "HBSC_data/HBSC2018OAed1.1.csv"
GROUPINGS_PATH = "HBSC_data/hbsc_variable_groupings.xlsx"
OUTPUT_PREFIX = "benrfv3_classifier"

AGE_MIN = 13.0
AGE_MAX = 16.5
TARGET = "distress_score_100"

N_OOS_RUNS = 5
TEST_SIZE = 0.20
RANDOM_SEEDS = [11, 23, 37, 49, 61]
MIN_STRATUM_COUNT = 30
IMPORTANCE_COVERAGE = 0.80

CLASS_LABELS = ["low", "medium", "high"]
CLASS_PERCENTILES = (0.60, 0.80)


def cronbach_alpha(df_items):
    items = df_items.dropna().copy()
    k = items.shape[1]
    if k <= 1:
        return np.nan
    item_variances = items.var(axis=0, ddof=1)
    total_variance = items.sum(axis=1).var(ddof=1)
    if total_variance == 0:
        return np.nan
    return (k / (k - 1)) * (1 - item_variances.sum() / total_variance)


def print_header(title):
    print("\n" + "=" * len(title))
    print(title)
    print("=" * len(title))


def rescale_series(series, source_min, source_max):
    numeric = pd.to_numeric(series, errors="coerce")
    return (numeric - source_min) / (source_max - source_min)


def clean_text(value):
    if pd.isna(value):
        return ""
    return str(value).strip().strip("'").strip()


def slugify_group(name):
    slug = re.sub(r"[^0-9a-zA-Z]+", "_", clean_text(name).lower()).strip("_")
    return slug or "unnamed"


def first_nonempty(values, default=""):
    for value in values:
        value = clean_text(value)
        if value:
            return value
    return default


def load_feature_plan(path):
    plan = pd.read_excel(path).iloc[:, :6].copy()
    plan.columns = [
        "hbsc_var",
        "new_group",
        "aggregation_method",
        "new_question",
        "omit_for_modelling",
        "long_term_var",
    ]
    for col in plan.columns:
        plan[col] = plan[col].map(clean_text)
    plan = plan[plan["hbsc_var"] != ""].reset_index(drop=True)
    return plan


def aggregate_feature(df_source, source_cols, method):
    numeric = pd.DataFrame(index=df_source.index)

    for col in source_cols:
        if col in df_source.columns:
            numeric[col] = pd.to_numeric(df_source[col], errors="coerce")
        else:
            numeric[col] = np.nan

    if method == "mean":
        return numeric.mean(axis=1, skipna=True)

    if method == "sum - 2":
        counts = numeric.notna().sum(axis=1)
        summed = numeric.sum(axis=1, min_count=1) - counts
        summed[counts == 0] = np.nan
        return summed

    if method == "take the most frequent":
        return numeric.max(axis=1, skipna=True)

    if method == "take the most frequent out of all the symptoms":
        return numeric.min(axis=1, skipna=True)

    if method == "at least 1 yes = new yes":
        any_nonmissing = numeric.notna().any(axis=1)
        any_yes = numeric.eq(1).any(axis=1)
        out = pd.Series(np.nan, index=numeric.index, dtype=float)
        out[any_nonmissing] = 2.0
        out[any_yes] = 1.0
        return out

    if not method and len(source_cols) == 1:
        return numeric.iloc[:, 0]

    raise ValueError(f"Unsupported aggregation method: {method!r} for {source_cols}")


def build_feature_matrix(df_source, feature_plan):
    keep_plan = feature_plan[feature_plan["omit_for_modelling"] == "N"].copy()

    feature_data = {}
    manifest_rows = []
    seen = set()

    for _, row in keep_plan.iterrows():
        raw_col = row["hbsc_var"]
        group_name = row["new_group"]

        if group_name:
            feature_name = f"grp_{slugify_group(group_name)}"
            if feature_name in seen:
                continue

            group_rows = keep_plan[keep_plan["new_group"] == group_name].copy()
            source_cols = group_rows["hbsc_var"].tolist()
            method = first_nonempty(group_rows["aggregation_method"], default="raw")
            question = first_nonempty(group_rows["new_question"])
            long_term = "Y" if (group_rows["long_term_var"] == "Y").any() else "N"
            missing_cols = [c for c in source_cols if c not in df_source.columns]

            feature_data[feature_name] = aggregate_feature(
                df_source=df_source,
                source_cols=source_cols,
                method=first_nonempty(group_rows["aggregation_method"]),
            )

            manifest_rows.append({
                "feature": feature_name,
                "feature_type": "grouped",
                "source_cols": ", ".join(source_cols),
                "new_group": group_name,
                "aggregation_method": method,
                "long_term_var": long_term,
                "new_question": question,
                "missing_source_cols": ", ".join(missing_cols),
            })
            seen.add(feature_name)
            continue

        if raw_col in seen:
            continue

        if raw_col in df_source.columns:
            feature_series = pd.to_numeric(df_source[raw_col], errors="coerce")
            missing_cols = []
        else:
            feature_series = pd.Series(np.nan, index=df_source.index, dtype=float)
            missing_cols = [raw_col]

        feature_data[raw_col] = feature_series
        manifest_rows.append({
            "feature": raw_col,
            "feature_type": "standalone",
            "source_cols": raw_col,
            "new_group": "",
            "aggregation_method": "raw",
            "long_term_var": row["long_term_var"] or "N",
            "new_question": row["new_question"],
            "missing_source_cols": ", ".join(missing_cols),
        })
        seen.add(raw_col)

    feature_df = pd.DataFrame(feature_data, index=df_source.index)
    feature_cols = list(feature_df.columns)
    manifest_df = pd.DataFrame(manifest_rows)
    return feature_df, feature_cols, manifest_df


def assign_risk_classes_from_cutoffs(series, cutoff_low, cutoff_high):
    bins = [-np.inf, cutoff_low, cutoff_high, np.inf]
    return pd.cut(
        series,
        bins=bins,
        labels=CLASS_LABELS,
        include_lowest=True,
        right=False,
    )


def compute_multiclass_metrics(y_true, y_pred, labels=CLASS_LABELS):
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    accuracy = accuracy_score(y_true, y_pred)
    macro_f1 = f1_score(y_true, y_pred, labels=labels, average="macro")
    weighted_f1 = f1_score(y_true, y_pred, labels=labels, average="weighted")
    kappa = cohen_kappa_score(y_true, y_pred, labels=labels)
    quadratic_kappa = cohen_kappa_score(y_true, y_pred, labels=labels, weights="quadratic")

    precision, recall, f1, support = precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=labels,
        zero_division=0,
    )

    metrics = {
        "accuracy": accuracy,
        "macro_f1": macro_f1,
        "weighted_f1": weighted_f1,
        "cohen_kappa": kappa,
        "quadratic_kappa": quadratic_kappa,
    }

    for i, cls in enumerate(labels):
        metrics[f"{cls}_precision"] = precision[i]
        metrics[f"{cls}_recall"] = recall[i]
        metrics[f"{cls}_f1"] = f1[i]
        metrics[f"{cls}_support"] = support[i]

    return metrics, cm


def summarize_feature_importance(rf_importances):
    imp_df = pd.concat(rf_importances, ignore_index=True)
    return (
        imp_df.groupby("feature")
        .agg(
            mean_importance=("importance", "mean"),
            std_importance=("importance", "std"),
        )
        .sort_values("mean_importance", ascending=False)
        .reset_index()
    )


def select_top_features_by_importance(imp_summary, coverage):
    selection_df = imp_summary.copy()
    total_importance = selection_df["mean_importance"].sum()
    selection_df["importance_share"] = selection_df["mean_importance"] / total_importance
    selection_df["cumulative_importance"] = selection_df["importance_share"].cumsum()

    cutoff_idx = selection_df.index[selection_df["cumulative_importance"] >= coverage][0]
    selection_df["selected_for_modelling"] = False
    selection_df.loc[:cutoff_idx, "selected_for_modelling"] = True

    selected_features = selection_df.loc[
        selection_df["selected_for_modelling"], "feature"
    ].tolist()

    return selection_df, selected_features


def build_model_inputs(working_df, feature_names):
    X_data = working_df[feature_names].copy()
    y_score = working_df[TARGET].copy()
    y_class = working_df["risk_class"].copy()
    strata_data = working_df["strata"].copy()

    for col in X_data.columns:
        X_data[col] = pd.to_numeric(X_data[col], errors="coerce")

    drop_cols = X_data.columns[X_data.isnull().mean() > 0.95].tolist()
    if drop_cols:
        X_data = X_data.drop(columns=drop_cols)
        feature_names = [c for c in feature_names if c not in drop_cols]

    return X_data, y_score, y_class, strata_data, feature_names, drop_cols


def build_split_strata(strata_data, y_class):
    combined = strata_data.astype(str) + "__" + y_class.astype(str)
    counts = combined.value_counts()
    return combined.where(combined.map(counts) >= 2, "other")


def run_repeated_oos_classifier(models, X_data, y_class, strata_data, feature_names):
    all_oos_results = []
    rf_importances = []
    oos_prediction_rows = []
    confusion_store = {}

    for model_name, base_model in models.items():
        print(f"\n--- {model_name} ---")

        for run_id, seed in enumerate(RANDOM_SEEDS[:N_OOS_RUNS], start=1):
            split_strata = build_split_strata(strata_data, y_class)

            X_train, X_test, y_train, y_test = train_test_split(
                X_data,
                y_class,
                test_size=TEST_SIZE,
                random_state=seed,
                stratify=split_strata,
            )

            model = clone(base_model)
            model.fit(X_train, y_train)

            y_pred_train = model.predict(X_train)
            y_pred_test = model.predict(X_test)

            train_metrics, _ = compute_multiclass_metrics(y_train, y_pred_train)
            test_metrics, cm = compute_multiclass_metrics(y_test, y_pred_test)

            row = {
                "model": model_name,
                "run": run_id,
                "seed": seed,
                "train_accuracy": train_metrics["accuracy"],
                "test_accuracy": test_metrics["accuracy"],
                "train_macro_f1": train_metrics["macro_f1"],
                "test_macro_f1": test_metrics["macro_f1"],
                "train_weighted_f1": train_metrics["weighted_f1"],
                "test_weighted_f1": test_metrics["weighted_f1"],
                "train_quadratic_kappa": train_metrics["quadratic_kappa"],
                "test_quadratic_kappa": test_metrics["quadratic_kappa"],
                "test_low_precision": test_metrics["low_precision"],
                "test_medium_precision": test_metrics["medium_precision"],
                "test_high_precision": test_metrics["high_precision"],
                "test_low_recall": test_metrics["low_recall"],
                "test_medium_recall": test_metrics["medium_recall"],
                "test_high_recall": test_metrics["high_recall"],
                "test_low_f1": test_metrics["low_f1"],
                "test_medium_f1": test_metrics["medium_f1"],
                "test_high_f1": test_metrics["high_f1"],
            }
            all_oos_results.append(row)

            oos_prediction_rows.append(
                pd.DataFrame({
                    "model": model_name,
                    "run": run_id,
                    "seed": seed,
                    "row_index": y_test.index,
                    "actual_class": y_test.astype(str).values,
                    "predicted_class": pd.Series(y_pred_test).astype(str).values,
                })
            )

            confusion_store[(model_name, run_id)] = pd.DataFrame(
                cm,
                index=[f"actual_{c}" for c in CLASS_LABELS],
                columns=[f"pred_{c}" for c in CLASS_LABELS],
            )

            if model_name == "RandomForest":
                rf_importances.append(
                    pd.DataFrame({
                        "run": run_id,
                        "feature": feature_names,
                        "importance": model.named_steps["model"].feature_importances_,
                    })
                )

            print(
                f"  Run {run_id}: "
                f"test_accuracy={row['test_accuracy']:.4f}, "
                f"test_macro_f1={row['test_macro_f1']:.4f}, "
                f"test_high_recall={row['test_high_recall']:.4f}"
            )

    return (
        pd.DataFrame(all_oos_results),
        rf_importances,
        pd.concat(oos_prediction_rows, ignore_index=True),
        confusion_store,
    )


def summarize_classification_results(oos_df):
    return (
        oos_df.groupby("model")
        .agg(
            mean_test_accuracy=("test_accuracy", "mean"),
            std_test_accuracy=("test_accuracy", "std"),
            mean_test_macro_f1=("test_macro_f1", "mean"),
            std_test_macro_f1=("test_macro_f1", "std"),
            mean_test_weighted_f1=("test_weighted_f1", "mean"),
            mean_test_quadratic_kappa=("test_quadratic_kappa", "mean"),
            mean_test_high_recall=("test_high_recall", "mean"),
            mean_test_high_precision=("test_high_precision", "mean"),
            mean_test_high_f1=("test_high_f1", "mean"),
            mean_test_medium_f1=("test_medium_f1", "mean"),
        )
        .round(4)
    )


print_header("LOAD DATA")
df = pd.read_csv(DATA_PATH, sep=";", engine="python")
print("Raw dataset shape:", df.shape)

df["age"] = pd.to_numeric(
    df["age"].astype(str).str.replace(",", ".", regex=False),
    errors="coerce"
)
df = df[(df["age"] >= AGE_MIN) & (df["age"] <= AGE_MAX)].copy()
print(f"Filtered dataset shape (age {AGE_MIN}-{AGE_MAX}):", df.shape)

print_header("BUILD DISTRESS TARGET")

y_vars = ["feellow", "irritable", "nervous", "lifesat"]
for col in y_vars:
    df[col] = pd.to_numeric(df[col], errors="coerce")

df["feellow_rev"] = 6 - df["feellow"]
df["irritable_rev"] = 6 - df["irritable"]
df["nervous_rev"] = 6 - df["nervous"]
df["lifesat_rev"] = 10 - df["lifesat"]

reversed_y_vars = ["feellow_rev", "irritable_rev", "nervous_rev", "lifesat_rev"]

df_y = df.dropna(subset=y_vars).copy()
print("Rows after dropping missing target items:", len(df_y))
print("Percent removed:", round((len(df) - len(df_y)) / len(df) * 100, 2), "%")

alpha_val = cronbach_alpha(df_y[reversed_y_vars])
print("Cronbach's alpha for distress items:", round(alpha_val, 4))

df_y["feellow_risk"] = rescale_series(df_y["feellow_rev"], 1, 5)
df_y["irritable_risk"] = rescale_series(df_y["irritable_rev"], 1, 5)
df_y["nervous_risk"] = rescale_series(df_y["nervous_rev"], 1, 5)
df_y["lifesat_risk"] = rescale_series(df_y["lifesat_rev"], 0, 10)

risk_vars = ["feellow_risk", "irritable_risk", "nervous_risk", "lifesat_risk"]
df_y[TARGET] = df_y[risk_vars].mean(axis=1) * 100

print(df_y[TARGET].describe())

plt.figure(figsize=(8, 5))
sns.histplot(df_y[TARGET], bins=40, kde=True)
plt.title("Distribution of Distress Score (0-100)")
plt.xlabel("Distress score")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

df_y["age_bin"] = pd.cut(df_y["age"], bins=np.arange(13, 16.6, 0.5), include_lowest=True)
age_bin_mean = (
    df_y.groupby("age_bin", dropna=False)[TARGET]
    .mean()
    .reset_index()
)
age_bin_mean["age_bin"] = age_bin_mean["age_bin"].astype(str)

plt.figure(figsize=(9, 5))
sns.lineplot(data=age_bin_mean, x="age_bin", y=TARGET, marker="o")
plt.title("Average Distress Score by Age Group")
plt.xlabel("Age group")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print_header("BUILD FEATURES FROM WORKBOOK")

feature_plan = load_feature_plan(GROUPINGS_PATH)
feature_df, feature_cols, feature_manifest = build_feature_matrix(df_y, feature_plan)

existing_feature_names = [c for c in feature_df.columns if c in df_y.columns]
df_y = df_y.drop(columns=existing_feature_names, errors="ignore")
df_y = pd.concat([df_y, feature_df], axis=1)

print(f"Workbook rows kept for modelling: {(feature_plan['omit_for_modelling'] == 'N').sum()}")
print(f"Engineered feature count: {len(feature_cols)}")
print("\nFeature manifest:")
print(feature_manifest.to_string(index=False))

missing_features = feature_manifest[feature_manifest["missing_source_cols"] != ""]
if not missing_features.empty:
    print("\nWarning: some workbook source columns were missing from the dataset:")
    print(missing_features[["feature", "missing_source_cols"]].to_string(index=False))

print_header("DIRECTION AUDIT")
print(f"{'Feature':<30} {'Corr w/ distress':>16}  {'Direction':>10}")
print("-" * 60)

for col in feature_cols:
    valid = df_y[[col, TARGET]].dropna()
    if len(valid) > 100:
        r = valid[col].corr(valid[TARGET])
        direction = "+" if r > 0 else "-"
        print(f"{col:<30} {r:>+16.4f}  {direction}")

print_header("BUILD WORKING DATASET")

model_cols = list(dict.fromkeys(feature_cols + [TARGET, "age", "sex"]))
working_df = df_y[model_cols].copy()
working_df = working_df[working_df[TARGET].notna()].copy()

cutoff_low, cutoff_high = np.quantile(working_df[TARGET], CLASS_PERCENTILES)
working_df["risk_class"] = assign_risk_classes_from_cutoffs(
    working_df[TARGET],
    cutoff_low,
    cutoff_high,
)

print("Working dataframe shape:", working_df.shape)
print("Features:", len(feature_cols))
print(f"Using class cutoffs: low/medium={cutoff_low:.2f}, medium/high={cutoff_high:.2f}")

print("\nRisk class distribution:")
print(working_df["risk_class"].value_counts().reindex(CLASS_LABELS).to_string())

working_df["age_band"] = pd.cut(
    working_df["age"],
    bins=[13, 14, 15, 16, 16.5],
    include_lowest=True
).astype(str)

working_df["sex_str"] = working_df["sex"].astype("Int64").astype(str)
working_df["strata"] = working_df["age_band"] + "__" + working_df["sex_str"]

strata_counts = working_df["strata"].value_counts(dropna=False)
small_strata = strata_counts[strata_counts < MIN_STRATUM_COUNT].index
working_df.loc[working_df["strata"].isin(small_strata), "strata"] = "other"

print("\nStrata counts:")
print(working_df["strata"].value_counts(dropna=False))

missing_pct = working_df[feature_cols].isnull().mean().sort_values(ascending=False)
print("\nMissing data % (top 15):")
print(missing_pct.head(15).to_string())

print_header("FEATURE CORRELATIONS")

corr_rows = []
for col in feature_cols:
    valid = working_df[[col, TARGET]].dropna()
    if len(valid) > 500:
        r = valid[col].corr(valid[TARGET])
        corr_rows.append({
            "feature": col,
            "correlation": r,
            "abs_corr": abs(r),
            "n": len(valid),
        })

corr_df = pd.DataFrame(corr_rows).sort_values("abs_corr", ascending=False)
print(corr_df.to_string(index=False))

plt.figure(figsize=(12, 24))
sns.barplot(data=corr_df.sort_values("correlation"), x="correlation", y="feature")
plt.title("Correlation of Workbook-Selected Features with Distress Score")
plt.axvline(0, color="black", linewidth=0.8)
plt.tight_layout()
plt.show()

print_header("DEFINE MODELS")

baseline_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(
        multi_class="multinomial",
        class_weight="balanced",
        solver="lbfgs",
        max_iter=2000,
        random_state=42,
    )),
])

rf_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("model", RandomForestClassifier(
        n_estimators=500,
        max_depth=10,
        min_samples_leaf=20,
        max_features="sqrt",
        class_weight="balanced_subsample",
        n_jobs=-1,
        random_state=42,
    )),
])

print("Baseline multinomial logistic classifier ready.")
print("Random Forest classifier ready.")

print_header("MODEL INPUT PREP")

X_all, y_score_all, y_class_all, strata_all, feature_cols, drop_cols = build_model_inputs(
    working_df,
    feature_cols,
)

if drop_cols:
    print(f"Dropping {len(drop_cols)} columns (>95% missing): {drop_cols}")
    print(f"Features remaining after missingness filter: {len(feature_cols)}")

print(f"X_all shape before modelling: {X_all.shape}")

print_header("RANDOM FOREST CLASSIFIER SETTINGS")

best_rf_params = {
    "n_estimators": 800,
    "min_samples_split": 5,
    "min_samples_leaf": 5,
    "max_features": 0.5,
    "max_depth": 10,
    "class_weight": "balanced_subsample",
    "n_jobs": -1,
    "random_state": 42,
}

print("Using RF params:")
for k, v in best_rf_params.items():
    print(f"  {k}: {v}")

tuned_rf_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("model", RandomForestClassifier(**best_rf_params)),
])

print("\nTuned RF classifier pipeline ready.")

print_header("PRELIMINARY FEATURE IMPORTANCE RUN")

screening_models = {
    "RandomForest": tuned_rf_pipeline,
}

screening_oos_df, screening_rf_importances, _, _ = run_repeated_oos_classifier(
    screening_models,
    X_all,
    y_class_all,
    strata_all,
    feature_cols,
)

screening_imp_summary = summarize_feature_importance(screening_rf_importances)
screening_imp_summary, selected_feature_cols = select_top_features_by_importance(
    screening_imp_summary,
    IMPORTANCE_COVERAGE,
)

selected_feature_manifest = feature_manifest[
    feature_manifest["feature"].isin(selected_feature_cols)
].copy()

print("\nScreening feature importance summary:")
print(screening_imp_summary.to_string(index=False))
print(
    f"\nSelected {len(selected_feature_cols)} of {len(feature_cols)} features "
    f"to reach {IMPORTANCE_COVERAGE:.0%} cumulative importance."
)
print("Selected features:")
for feature_name in selected_feature_cols:
    print(" -", feature_name)

X_selected = X_all[selected_feature_cols].copy()

plt.figure(figsize=(12, 24))
sns.barplot(
    data=screening_imp_summary.sort_values("mean_importance", ascending=True),
    x="mean_importance",
    y="feature",
)
plt.title("Initial RF Feature Importance (Workbook-Selected Features)")
plt.xlabel("Mean importance across screening runs")
plt.tight_layout()
plt.show()

print_header("REPEATED OOS VALIDATIONS")

models = {
    "BaselineLogistic": baseline_pipeline,
    "RandomForest": tuned_rf_pipeline,
}

oos_df, rf_importances, oos_predictions_df, confusion_store = run_repeated_oos_classifier(
    models,
    X_selected,
    y_class_all,
    strata_all,
    selected_feature_cols,
)

print_header("MODEL COMPARISON")

comparison = summarize_classification_results(oos_df)
print(comparison.to_string())

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i, metric in enumerate(["test_accuracy", "test_macro_f1", "test_high_recall"]):
    sns.barplot(data=oos_df, x="model", y=metric, ax=axes[i], errorbar="sd")
    axes[i].set_title(f"OOS {metric}")
plt.tight_layout()
plt.show()

print_header("FEATURE IMPORTANCE")

imp_summary = summarize_feature_importance(rf_importances)
print(imp_summary.to_string(index=False))

plt.figure(figsize=(12, 20))
sns.barplot(
    data=imp_summary.sort_values("mean_importance", ascending=True),
    x="mean_importance",
    y="feature",
)
plt.title("Random Forest Feature Importance (90% Cumulative Set)")
plt.xlabel("Mean importance across 5 runs")
plt.tight_layout()
plt.show()

print_header("FINAL MODEL ON FULL SAMPLE")

final_rf = clone(tuned_rf_pipeline)
final_rf.fit(X_selected, y_class_all)

full_pred_class = final_rf.predict(X_selected)

diagnostic_cols = list(dict.fromkeys(selected_feature_cols + [TARGET, "risk_class"]))
for extra_col in ["age", "sex"]:
    if extra_col in working_df.columns and extra_col not in diagnostic_cols:
        diagnostic_cols.append(extra_col)

diagnostic_df = working_df[diagnostic_cols].copy()
diagnostic_df["predicted_class"] = full_pred_class.astype(str)

final_metrics, final_cm = compute_multiclass_metrics(
    diagnostic_df["risk_class"],
    diagnostic_df["predicted_class"],
)

print("Full-sample classification metrics:")
for k, v in final_metrics.items():
    if "support" not in k:
        print(f"  {k}: {v:.4f}")

final_cm_df = pd.DataFrame(
    final_cm,
    index=[f"actual_{c}" for c in CLASS_LABELS],
    columns=[f"pred_{c}" for c in CLASS_LABELS],
)

print("\nFull-sample confusion matrix:")
print(final_cm_df.to_string())

print("\nClassification report:")
print(classification_report(
    diagnostic_df["risk_class"],
    diagnostic_df["predicted_class"],
    labels=CLASS_LABELS,
    zero_division=0,
    digits=4,
))

plt.figure(figsize=(8, 6))
sns.heatmap(final_cm_df, annot=True, fmt="d", cmap="Blues")
plt.title("Final Random Forest Classifier Confusion Matrix")
plt.tight_layout()
plt.show()

print_header("SAVE OUTPUTS")

output_files = {
    "screening": f"{OUTPUT_PREFIX}_feature_screening.csv",
    "oos": f"{OUTPUT_PREFIX}_oos_classification_results.csv",
    "oos_predictions": f"{OUTPUT_PREFIX}_oos_class_predictions.csv",
    "comparison": f"{OUTPUT_PREFIX}_classification_comparison.csv",
    "importance": f"{OUTPUT_PREFIX}_feature_importance.csv",
    "predictions": f"{OUTPUT_PREFIX}_final_class_predictions.csv",
    "final_confusion": f"{OUTPUT_PREFIX}_final_confusion_matrix.csv",
    "manifest": f"{OUTPUT_PREFIX}_feature_manifest.csv",
    "selected_manifest": f"{OUTPUT_PREFIX}_selected_feature_manifest.csv",
}

screening_imp_summary.to_csv(output_files["screening"], index=False)
oos_df.to_csv(output_files["oos"], index=False)
oos_predictions_df.to_csv(output_files["oos_predictions"], index=False)
comparison.to_csv(output_files["comparison"])
imp_summary.to_csv(output_files["importance"], index=False)
diagnostic_df.to_csv(output_files["predictions"], index=False)
final_cm_df.to_csv(output_files["final_confusion"])
feature_manifest.to_csv(output_files["manifest"], index=False)
selected_feature_manifest.to_csv(output_files["selected_manifest"], index=False)

print("Saved:")
for f in output_files.values():
    print(" -", f)

print_header("SUMMARY")

baseline_oos = oos_df[oos_df["model"] == "BaselineLogistic"]
rf_oos = oos_df[oos_df["model"] == "RandomForest"]

print(f"Initial feature count:  {len(feature_cols)}")
print(f"Selected feature count: {len(selected_feature_cols)}")

print("\nBaseline Logistic Classifier")
print(f"  Mean OOS Accuracy:         {baseline_oos['test_accuracy'].mean():.4f} +/- {baseline_oos['test_accuracy'].std():.4f}")
print(f"  Mean OOS Macro F1:         {baseline_oos['test_macro_f1'].mean():.4f} +/- {baseline_oos['test_macro_f1'].std():.4f}")
print(f"  Mean OOS Weighted F1:      {baseline_oos['test_weighted_f1'].mean():.4f} +/- {baseline_oos['test_weighted_f1'].std():.4f}")
print(f"  Mean OOS Quadratic Kappa:  {baseline_oos['test_quadratic_kappa'].mean():.4f}")
print(f"  Mean OOS High Recall:      {baseline_oos['test_high_recall'].mean():.4f}")
print(f"  Mean OOS High Precision:   {baseline_oos['test_high_precision'].mean():.4f}")
print(f"  Mean OOS High F1:          {baseline_oos['test_high_f1'].mean():.4f}")
print(f"  Mean OOS Medium F1:        {baseline_oos['test_medium_f1'].mean():.4f}")

print("\nRandom Forest Classifier")
print(f"  Mean OOS Accuracy:         {rf_oos['test_accuracy'].mean():.4f} +/- {rf_oos['test_accuracy'].std():.4f}")
print(f"  Mean OOS Macro F1:         {rf_oos['test_macro_f1'].mean():.4f} +/- {rf_oos['test_macro_f1'].std():.4f}")
print(f"  Mean OOS Weighted F1:      {rf_oos['test_weighted_f1'].mean():.4f} +/- {rf_oos['test_weighted_f1'].std():.4f}")
print(f"  Mean OOS Quadratic Kappa:  {rf_oos['test_quadratic_kappa'].mean():.4f}")
print(f"  Mean OOS High Recall:      {rf_oos['test_high_recall'].mean():.4f}")
print(f"  Mean OOS High Precision:   {rf_oos['test_high_precision'].mean():.4f}")
print(f"  Mean OOS High F1:          {rf_oos['test_high_f1'].mean():.4f}")
print(f"  Mean OOS Medium F1:        {rf_oos['test_medium_f1'].mean():.4f}")

print("\nAll features by importance:")
print(imp_summary.to_string(index=False))
# Out:
# =========
# LOAD DATA
# =========
# Raw dataset shape: (244097, 120)
# Filtered dataset shape (age 13.0-16.5): (156603, 120)
#
# =====================
# BUILD DISTRESS TARGET
# =====================
# Rows after dropping missing target items: 150867
# Percent removed: 3.66 %
# Cronbach's alpha for distress items: 0.7366
# count    150867.000000
# mean         34.052990
# std          23.800703
# min           0.000000
# 25%          15.000000
# 50%          30.000000
# 75%          50.000000
# max         100.000000
# Name: distress_score_100, dtype: float64
# ============================
# BUILD FEATURES FROM WORKBOOK
# ============================
# Workbook rows kept for modelling: 72
# Engineered feature count: 56
#
# Feature manifest:
#            feature feature_type                            source_cols      new_group                             aggregation_method long_term_var                                                                                                                   new_question missing_source_cols
#                age   standalone                                    age                                                           raw             Y
#                sex   standalone                                    sex                                                           raw             Y
#          fasfamcar   standalone                              fasfamcar                                                           raw             Y
#         fasbedroom   standalone                             fasbedroom                                                           raw             Y
#       fascomputers   standalone                           fascomputers                                                           raw             Y
#        fasbathroom   standalone                            fasbathroom                                                           raw             Y
#        fasdishwash   standalone                            fasdishwash                                                           raw             Y
#        fasholidays   standalone                            fasholidays                                                           raw             Y
#             health   standalone                                 health                                                           raw             N
#          grp_aches      grouped headache, stomachache, backache, dizzy          aches take the most frequent out of all the symptoms             N             In the last 6 months, how often have you had any of the following: headaches, stomachaches, backaches, felt dizzy?
#     sleepdificulty   standalone                         sleepdificulty                                                           raw             N
#          thinkbody   standalone                              thinkbody                                                           raw             N
#          physact60   standalone                              physact60                                                           raw             N
#          grp_bfast      grouped               breakfastwd, breakfastwe          bfast                                        sum - 2             N                                  How often do you usually have breakfast (more than a glass of milk or fruit juice) in a week?
#         grp_fruits      grouped                 fruits_2, vegetables_2         fruits                                           mean             N                                                                 How many times a week do you usually eat fruits or vegetables?
#         grp_sweets      grouped                 sweets_2, softdrinks_2         sweets                                           mean             N                                                          How many times a week do you usually eat sweets or drink soft drinks?
#              fmeal   standalone                                  fmeal                                                           raw             N
#            toothbr   standalone                                toothbr                                                           raw             N
#            timeexe   standalone                                timeexe                                                           raw             N
#         bodyweight   standalone                             bodyweight                                                           raw             Y
#         bodyheight   standalone                             bodyheight                                                           raw             Y
#         likeschool   standalone                             likeschool                                                           raw             N
#     schoolpressure   standalone                         schoolpressure                                                           raw             N
#       studtogether   standalone                           studtogether                                                           raw             N
#        studhelpful   standalone                            studhelpful                                                           raw             N
#         studaccept   standalone                             studaccept                                                           raw             N
#        grp_teacher      grouped             teacheraccept, teachercare        teacher                                           mean             N                                                                              I feel that my teachers care about and accept me.
#       teachertrust   standalone                           teachertrust                                                           raw             N
#   grp_bully_others      grouped          bulliedothers, cbulliedothers   bully others                         take the most frequent             N How often have you taken part in bullying another person(s) at school (including cyberbullying)  in the past couple of months?
#   grp_been_bullied      grouped              beenbullied, cbeenbullied   been bullied                         take the most frequent             N                                                        How often have you been bullied at school in the past couple of months?
#           fight12m   standalone                               fight12m                                                           raw             N
#         injured12m   standalone                             injured12m                                                           raw             N
#         friendhelp   standalone                             friendhelp                                                           raw             N
#         grp_friend      grouped              friendcounton, friendtalk         friend                                           mean             N                                              I can count on my friends when things go wrong or to talk about my problems with.
#        friendshare   standalone                            friendshare                                                           raw             N
# grp_online_contact      grouped  emconlfreq1, emconlfreq2, emconlfreq3 online contact                                           mean             N                                                                             How often do you have ONLINE contact with friends?
#    grp_online_pref      grouped  emconlpref1, emconlpref2, emconlpref3    online pref                                           mean             N                              On the internet, I talk more\neasily about my thoughts/feelings\nthan in a face-to-face encounter
#         emcsocmed3   standalone                             emcsocmed3                                                           raw             N
#         emcsocmed4   standalone                             emcsocmed4                                                           raw             N
#         emcsocmed5   standalone                             emcsocmed5                                                           raw             N
#         emcsocmed6   standalone                             emcsocmed6                                                           raw             N
#         emcsocmed7   standalone                             emcsocmed7                                                           raw             N
#         emcsocmed8   standalone                             emcsocmed8                                                           raw             N
#         emcsocmed9   standalone                             emcsocmed9                                                           raw             N
#        motherhome1   standalone                            motherhome1                                                           raw             Y
#        fatherhome1   standalone                            fatherhome1                                                           raw             Y
#        stepmohome1   standalone                            stepmohome1                                                           raw             Y
#        stepfahome1   standalone                            stepfahome1                                                           raw             Y
#      grp_else_home      grouped               fosterhome1, elsehome1_2      else home                       at least 1 yes = new yes             N                                                                   Do you live somewhere other than with your parents/guardian?
#           employfa   standalone                               employfa                                                           raw             N
#           employmo   standalone                               employmo                                                           raw             N
#    grp_talk_father      grouped                             talkfather    talk father                                            raw             N
#    grp_talk_mother      grouped                             talkmother    talk mother                                            raw             N
#            famhelp   standalone                                famhelp                                                           raw             N
#        grp_fam_sup      grouped                        famsup, famtalk        fam sup                                           mean             N                                    I get the emotional help and support I need (eg. talking about my problems) from my family.
#             famdec   standalone                                 famdec                                                           raw             N
#
# ===============
# DIRECTION AUDIT
# ===============
# Feature                        Corr w/ distress   Direction
# ------------------------------------------------------------
# age                                     +0.1044  +
# sex                                     +0.2165  +
# fasfamcar                               -0.0240  -
# fasbedroom                              -0.0410  -
# fascomputers                            +0.0075  +
# fasbathroom                             -0.0077  -
# fasdishwash                             -0.0106  -
# fasholidays                             -0.0786  -
# health                                  +0.3519  +
# grp_aches                               -0.5014  -
# sleepdificulty                          -0.4587  -
# thinkbody                               +0.1403  +
# physact60                               -0.1575  -
# grp_bfast                               -0.1955  -
# grp_fruits                              -0.0987  -
# grp_sweets                              +0.0516  +
# fmeal                                   +0.2029  +
# toothbr                                 +0.0550  +
# timeexe                                 +0.1312  +
# bodyweight                              +0.0369  +
# bodyheight                              -0.0314  -
# likeschool                              +0.2657  +
# schoolpressure                          +0.3156  +
# studtogether                            +0.2088  +
# studhelpful                             +0.2418  +
# studaccept                              +0.2812  +
# grp_teacher                             +0.2561  +
# teachertrust                            +0.2457  +
# grp_bully_others                        +0.1304  +
# grp_been_bullied                        +0.2417  +
# fight12m                                +0.1134  +
# injured12m                              +0.1224  +
# friendhelp                              -0.1368  -
# grp_friend                              -0.1316  -
# friendshare                             -0.0981  -
# grp_online_contact                      +0.0750  +
# grp_online_pref                         -0.0193  -
# emcsocmed3                              -0.0251  -
# emcsocmed4                              -0.0255  -
# emcsocmed5                              -0.0264  -
# emcsocmed6                              -0.0251  -
# emcsocmed7                              -0.0263  -
# emcsocmed8                              -0.0213  -
# emcsocmed9                              -0.0255  -
# motherhome1                             +0.0455  +
# fatherhome1                             +0.0952  +
# stepmohome1                             -0.0189  -
# stepfahome1                             -0.0486  -
# grp_else_home                           -0.0106  -
# employfa                                +0.0691  +
# employmo                                +0.0353  +
# grp_talk_father                         +0.2893  +
# grp_talk_mother                         +0.2752  +
# famhelp                                 -0.1889  -
# grp_fam_sup                             -0.2792  -
# famdec                                  -0.2127  -
#
# =====================
# BUILD WORKING DATASET
# =====================
# Working dataframe shape: (150867, 58)
# Features: 56
# Using class cutoffs: low/medium=37.50, medium/high=56.25
#
# Risk class distribution:
# risk_class
# low       89771
# medium    30520
# high      30576
#
# Strata counts:
# strata
# (12.999, 14.0]__2    35913
# (12.999, 14.0]__1    34569
# (15.0, 16.0]__2      31952
# (15.0, 16.0]__1      29484
# (14.0, 15.0]__2       7186
# (14.0, 15.0]__1       6917
# (16.0, 16.5]__1       2487
# (16.0, 16.5]__2       2359
# Name: count, dtype: int64
#
# Missing data % (top 15):
# bodyweight            0.146898
# bodyheight            0.134363
# emcsocmed8            0.113378
# emcsocmed9            0.113007
# emcsocmed7            0.112569
# emcsocmed6            0.112443
# emcsocmed5            0.111840
# emcsocmed4            0.111661
# emcsocmed3            0.110833
# grp_online_pref       0.102726
# grp_online_contact    0.092499
# employfa              0.091306
# employmo              0.090318
# famdec                0.064613
# teachertrust          0.062101
#
# ====================
# FEATURE CORRELATIONS
# ====================
#            feature  correlation  abs_corr      n
#          grp_aches    -0.501423  0.501423 150860
#     sleepdificulty    -0.458658  0.458658 147935
#             health     0.351853  0.351853 150148
#     schoolpressure     0.315559  0.315559 148625
#    grp_talk_father     0.289312  0.289312 142521
#         studaccept     0.281196  0.281196 141798
#        grp_fam_sup    -0.279222  0.279222 141660
#    grp_talk_mother     0.275206  0.275206 143900
#         likeschool     0.265700  0.265700 148797
#        grp_teacher     0.256054  0.256054 142198
#       teachertrust     0.245722  0.245722 141498
#        studhelpful     0.241783  0.241783 142124
#   grp_been_bullied     0.241666  0.241666 147749
#                sex     0.216547  0.216547 150867
#             famdec    -0.212665  0.212665 141119
#       studtogether     0.208801  0.208801 142219
#              fmeal     0.202907  0.202907 142353
#          grp_bfast    -0.195539  0.195539 146397
#            famhelp    -0.188867  0.188867 141558
#          physact60    -0.157529  0.157529 148128
#          thinkbody     0.140283  0.140283 145269
#         friendhelp    -0.136831  0.136831 146851
#         grp_friend    -0.131575  0.131575 147070
#            timeexe     0.131152  0.131152 148889
#   grp_bully_others     0.130365  0.130365 145205
#         injured12m     0.122407  0.122407 147161
#           fight12m     0.113395  0.113395 147238
#                age     0.104379  0.104379 150867
#         grp_fruits    -0.098654  0.098654 148123
#        friendshare    -0.098050  0.098050 146555
#        fatherhome1     0.095177  0.095177 146135
#        fasholidays    -0.078608  0.078608 147307
# grp_online_contact     0.075006  0.075006 136912
#           employfa     0.069115  0.069115 137092
#            toothbr     0.055009  0.055009 146273
#         grp_sweets     0.051605  0.051605 148032
#        stepfahome1    -0.048584  0.048584 145962
#        motherhome1     0.045464  0.045464 146105
#         fasbedroom    -0.040974  0.040974 147749
#         bodyweight     0.036948  0.036948 128705
#           employmo     0.035304  0.035304 137241
#         bodyheight    -0.031409  0.031409 130596
#         emcsocmed5    -0.026398  0.026398 133994
#         emcsocmed7    -0.026270  0.026270 133884
#         emcsocmed9    -0.025488  0.025488 133818
#         emcsocmed4    -0.025473  0.025473 134021
#         emcsocmed6    -0.025141  0.025141 133903
#         emcsocmed3    -0.025102  0.025102 134146
#          fasfamcar    -0.023993  0.023993 147985
#         emcsocmed8    -0.021334  0.021334 133762
#    grp_online_pref    -0.019327  0.019327 135369
#        stepmohome1    -0.018920  0.018920 145962
#        fasdishwash    -0.010643  0.010643 144576
#      grp_else_home    -0.010643  0.010643 145721
#        fasbathroom    -0.007738  0.007738 145397
#       fascomputers     0.007481  0.007481 148457
# =============
# DEFINE MODELS
# =============
# Baseline multinomial logistic classifier ready.
# Random Forest classifier ready.
#
# ================
# MODEL INPUT PREP
# ================
# X_all shape before modelling: (150867, 56)
#
# =================================
# RANDOM FOREST CLASSIFIER SETTINGS
# =================================
# Using RF params:
#   n_estimators: 800
#   min_samples_split: 5
#   min_samples_leaf: 5
#   max_features: 0.5
#   max_depth: 10
#   class_weight: balanced_subsample
#   n_jobs: -1
#   random_state: 42
#
# Tuned RF classifier pipeline ready.
#
# ==================================
# PRELIMINARY FEATURE IMPORTANCE RUN
# ==================================
#
# --- RandomForest ---
#   Run 1: test_accuracy=0.6149, test_macro_f1=0.5639, test_high_recall=0.6329
#   Run 2: test_accuracy=0.6218, test_macro_f1=0.5693, test_high_recall=0.6327
#   Run 3: test_accuracy=0.6184, test_macro_f1=0.5678, test_high_recall=0.6330
#   Run 4: test_accuracy=0.6198, test_macro_f1=0.5663, test_high_recall=0.6378
#   Run 5: test_accuracy=0.6227, test_macro_f1=0.5710, test_high_recall=0.6373
#
# Screening feature importance summary:
#            feature  mean_importance  std_importance  importance_share  cumulative_importance  selected_for_modelling
#          grp_aches         0.296649        0.002547          0.296649               0.296649                    True
#     sleepdificulty         0.176609        0.000944          0.176609               0.473259                    True
#     schoolpressure         0.059014        0.001446          0.059014               0.532273                    True
#             health         0.056516        0.002105          0.056516               0.588789                    True
#        grp_fam_sup         0.046987        0.000817          0.046987               0.635776                    True
#    grp_talk_father         0.039970        0.002495          0.039970               0.675746                    True
#         emcsocmed8         0.024364        0.001145          0.024364               0.700111                    True
#         studaccept         0.018588        0.001136          0.018588               0.718699                    True
#   grp_been_bullied         0.014899        0.000899          0.014899               0.733598                    True
#    grp_talk_mother         0.014839        0.001663          0.014839               0.748437                    True
#                age         0.014829        0.000234          0.014829               0.763266                    True
#         bodyheight         0.012790        0.000134          0.012790               0.776056                    True
#         likeschool         0.012188        0.000422          0.012188               0.788244                    True
#                sex         0.012019        0.000557          0.012019               0.800263                    True
#         bodyweight         0.011485        0.000117          0.011485               0.811748                    True
#          physact60         0.009966        0.000229          0.009966               0.821713                    True
#        grp_teacher         0.009825        0.000354          0.009825               0.831538                    True
#         grp_sweets         0.009379        0.000171          0.009379               0.840917                    True
#        studhelpful         0.009372        0.000351          0.009372               0.850289                    True
# grp_online_contact         0.009137        0.000100          0.009137               0.859426                    True
#    grp_online_pref         0.008644        0.000131          0.008644               0.868070                    True
#         grp_friend         0.008356        0.000161          0.008356               0.876426                    True
#            timeexe         0.008268        0.000254          0.008268               0.884694                    True
#         grp_fruits         0.008203        0.000208          0.008203               0.892897                    True
#          grp_bfast         0.007916        0.000312          0.007916               0.900813                    True
#       teachertrust         0.006897        0.000416          0.006897               0.907710                   False
#         friendhelp         0.006482        0.000088          0.006482               0.914192                   False
#        fasholidays         0.006467        0.000098          0.006467               0.920659                   False
#            famhelp         0.006225        0.000312          0.006225               0.926885                   False
#             famdec         0.006089        0.000130          0.006089               0.932974                   False
#          thinkbody         0.005980        0.000260          0.005980               0.938954                   False
#              fmeal         0.005626        0.000101          0.005626               0.944579                   False
#           fight12m         0.004964        0.000061          0.004964               0.949543                   False
#       studtogether         0.004670        0.000154          0.004670               0.954213                   False
#        friendshare         0.004555        0.000097          0.004555               0.958768                   False
#   grp_bully_others         0.004501        0.000348          0.004501               0.963269                   False
#       fascomputers         0.003502        0.000133          0.003502               0.966771                   False
#         injured12m         0.003295        0.000099          0.003295               0.970066                   False
#          fasfamcar         0.003112        0.000146          0.003112               0.973178                   False
#            toothbr         0.002896        0.000089          0.002896               0.976075                   False
#        fasbathroom         0.002331        0.000109          0.002331               0.978405                   False
#         emcsocmed6         0.002223        0.000143          0.002223               0.980628                   False
#         emcsocmed9         0.001895        0.000059          0.001895               0.982523                   False
#           employmo         0.001822        0.000059          0.001822               0.984346                   False
#         emcsocmed3         0.001786        0.000061          0.001786               0.986132                   False
#         fasbedroom         0.001781        0.000035          0.001781               0.987913                   False
#        fatherhome1         0.001764        0.000019          0.001764               0.989677                   False
#         emcsocmed4         0.001754        0.000053          0.001754               0.991431                   False
#           employfa         0.001624        0.000060          0.001624               0.993055                   False
#        fasdishwash         0.001418        0.000052          0.001418               0.994473                   False
#         emcsocmed5         0.001403        0.000031          0.001403               0.995876                   False
#         emcsocmed7         0.001393        0.000058          0.001393               0.997269                   False
#      grp_else_home         0.001168        0.000038          0.001168               0.998437                   False
#        motherhome1         0.000730        0.000022          0.000730               0.999167                   False
#        stepfahome1         0.000587        0.000048          0.000587               0.999754                   False
#        stepmohome1         0.000246        0.000024          0.000246               1.000000                   False
#
# Selected 25 of 56 features to reach 90% cumulative importance.
# Selected features:
#  - grp_aches
#  - sleepdificulty
#  - schoolpressure
#  - health
#  - grp_fam_sup
#  - grp_talk_father
#  - emcsocmed8
#  - studaccept
#  - grp_been_bullied
#  - grp_talk_mother
#  - age
#  - bodyheight
#  - likeschool
#  - sex
#  - bodyweight
#  - physact60
#  - grp_teacher
#  - grp_sweets
#  - studhelpful
#  - grp_online_contact
#  - grp_online_pref
#  - grp_friend
#  - timeexe
#  - grp_fruits
#  - grp_bfast
# ========================
# REPEATED OOS VALIDATIONS
# ========================
#
# --- BaselineLogistic ---
#   Run 1: test_accuracy=0.6235, test_macro_f1=0.5568, test_high_recall=0.6556
#   Run 2: test_accuracy=0.6250, test_macro_f1=0.5613, test_high_recall=0.6603
#   Run 3: test_accuracy=0.6260, test_macro_f1=0.5602, test_high_recall=0.6540
#   Run 4: test_accuracy=0.6282, test_macro_f1=0.5635, test_high_recall=0.6595
#   Run 5: test_accuracy=0.6297, test_macro_f1=0.5638, test_high_recall=0.6646
#
# --- RandomForest ---
#   Run 1: test_accuracy=0.6167, test_macro_f1=0.5650, test_high_recall=0.6342
#   Run 2: test_accuracy=0.6194, test_macro_f1=0.5666, test_high_recall=0.6283
#   Run 3: test_accuracy=0.6178, test_macro_f1=0.5667, test_high_recall=0.6291
#   Run 4: test_accuracy=0.6179, test_macro_f1=0.5644, test_high_recall=0.6327
#   Run 5: test_accuracy=0.6215, test_macro_f1=0.5695, test_high_recall=0.6339
#
# ================
# MODEL COMPARISON
# ================
#                   mean_test_accuracy  std_test_accuracy  mean_test_macro_f1  std_test_macro_f1  mean_test_weighted_f1  mean_test_quadratic_kappa  mean_test_high_recall  mean_test_high_precision  mean_test_high_f1  mean_test_medium_f1
# model
# BaselineLogistic              0.6265             0.0025              0.5611             0.0028                 0.6402                     0.5640                 0.6588                    0.5371             0.5918               0.3291
# RandomForest                  0.6187             0.0019              0.5665             0.0020                 0.6386                     0.5654                 0.6316                    0.5584             0.5928               0.3565
# ==================
# FEATURE IMPORTANCE
# ==================
#            feature  mean_importance  std_importance
#          grp_aches         0.301720        0.001694
#     sleepdificulty         0.183232        0.001059
#     schoolpressure         0.062853        0.001352
#             health         0.061080        0.002075
#        grp_fam_sup         0.053855        0.001560
#    grp_talk_father         0.044545        0.002760
#         emcsocmed8         0.027258        0.000905
#         studaccept         0.021645        0.001429
#                age         0.019647        0.000260
#   grp_been_bullied         0.018522        0.000928
#    grp_talk_mother         0.017522        0.001996
#         bodyheight         0.017470        0.000180
#         bodyweight         0.016218        0.000153
#         likeschool         0.015454        0.000346
#        grp_teacher         0.013944        0.000330
#                sex         0.013932        0.000598
#         grp_friend         0.013505        0.000191
#          physact60         0.013197        0.000180
#         grp_sweets         0.013137        0.000160
# grp_online_contact         0.012925        0.000045
#        studhelpful         0.012486        0.000205
#    grp_online_pref         0.012283        0.000093
#         grp_fruits         0.011624        0.000296
#            timeexe         0.011061        0.000211
#          grp_bfast         0.010885        0.000332
# ==========================
# FINAL MODEL ON FULL SAMPLE
# ==========================
# Full-sample classification metrics:
#   accuracy: 0.6508
#   macro_f1: 0.6099
#   weighted_f1: 0.6682
#   cohen_kappa: 0.4289
#   quadratic_kappa: 0.5921
#   low_precision: 0.8547
#   low_recall: 0.6812
#   low_f1: 0.7581
#   medium_precision: 0.3563
#   medium_recall: 0.5240
#   medium_f1: 0.4242
#   high_precision: 0.6112
#   high_recall: 0.6884
#   high_f1: 0.6475
#
# Full-sample confusion matrix:
#                pred_low  pred_medium  pred_high
# actual_low        61151        22234       6386
# actual_medium      7523        15992       7005
# actual_high        2872         6656      21048
#
# Classification report:
#               precision    recall  f1-score   support
#
#          low     0.8547    0.6812    0.7581     89771
#       medium     0.3563    0.5240    0.4242     30520
#         high     0.6112    0.6884    0.6475     30576
#
#     accuracy                         0.6508    150867
#    macro avg     0.6074    0.6312    0.6099    150867
# weighted avg     0.7045    0.6508    0.6682    150867
# ============
# SAVE OUTPUTS
# ============
# Saved:
#  - benrfv3_classifier_feature_screening.csv
#  - benrfv3_classifier_oos_classification_results.csv
#  - benrfv3_classifier_oos_class_predictions.csv
#  - benrfv3_classifier_classification_comparison.csv
#  - benrfv3_classifier_feature_importance.csv
#  - benrfv3_classifier_final_class_predictions.csv
#  - benrfv3_classifier_final_confusion_matrix.csv
#  - benrfv3_classifier_feature_manifest.csv
#  - benrfv3_classifier_selected_feature_manifest.csv
#
# =======
# SUMMARY
# =======
# Initial feature count:  56
# Selected feature count: 25
#
# Baseline Logistic Classifier
#   Mean OOS Accuracy:         0.6265 +/- 0.0025
#   Mean OOS Macro F1:         0.5611 +/- 0.0028
#   Mean OOS Weighted F1:      0.6402 +/- 0.0021
#   Mean OOS Quadratic Kappa:  0.5640
#   Mean OOS High Recall:      0.6588
#   Mean OOS High Precision:   0.5371
#   Mean OOS High F1:          0.5918
#   Mean OOS Medium F1:        0.3291
#
# Random Forest Classifier
#   Mean OOS Accuracy:         0.6187 +/- 0.0019
#   Mean OOS Macro F1:         0.5665 +/- 0.0020
#   Mean OOS Weighted F1:      0.6386 +/- 0.0018
#   Mean OOS Quadratic Kappa:  0.5654
#   Mean OOS High Recall:      0.6316
#   Mean OOS High Precision:   0.5584
#   Mean OOS High F1:          0.5928
#   Mean OOS Medium F1:        0.3565
#
# All features by importance:
#            feature  mean_importance  std_importance
#          grp_aches         0.301720        0.001694
#     sleepdificulty         0.183232        0.001059
#     schoolpressure         0.062853        0.001352
#             health         0.061080        0.002075
#        grp_fam_sup         0.053855        0.001560
#    grp_talk_father         0.044545        0.002760
#         emcsocmed8         0.027258        0.000905
#         studaccept         0.021645        0.001429
#                age         0.019647        0.000260
#   grp_been_bullied         0.018522        0.000928
#    grp_talk_mother         0.017522        0.001996
#         bodyheight         0.017470        0.000180
#         bodyweight         0.016218        0.000153
#         likeschool         0.015454        0.000346
#        grp_teacher         0.013944        0.000330
#                sex         0.013932        0.000598
#         grp_friend         0.013505        0.000191
#          physact60         0.013197        0.000180
#         grp_sweets         0.013137        0.000160
# grp_online_contact         0.012925        0.000045
#        studhelpful         0.012486        0.000205
#    grp_online_pref         0.012283        0.000093
#         grp_fruits         0.011624        0.000296
#            timeexe         0.011061        0.000211
#          grp_bfast         0.010885        0.000332
